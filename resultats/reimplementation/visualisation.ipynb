# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Tableau 7 far ood hmdb ++

# %%
far_ood_hmdb = pd.read_csv("reimpl_papier.csv")
far_ood_hmdb
# Out:
#          method dataset layer_proc   fpr95   auroc  id_acc       exec_time
# 0           msp     UCF       none  40.593  88.000  86.773             NaN
# 1           msp     HAC       none  28.620  91.568  86.773             NaN
# 2           msp    EPIC       none  13.455  96.422  86.773             NaN
# 3           ebo     UCF       none  37.058  89.712  86.773             NaN
# 4           ebo     HAC       none  23.033  94.447  86.773             NaN
# 5           ebo    EPIC       none   7.184  97.598  86.773             NaN
# 6      maxlogit     UCF       none  37.058  89.729  86.773             NaN
# 7      maxlogit     HAC       none  23.147  94.250  86.773             NaN
# 8      maxlogit    EPIC       none   7.070  97.726  86.773             NaN
# 9   Mahalanobis     UCF       none  27.708  91.211  86.773             NaN
# 10  Mahalanobis     HAC       none   7.754  98.218  86.773             NaN
# ...

# %%
results = {"method": [], "UCF_fpr95": [], "UCF_auroc":[], "EPIC_fpr95": [], "EPIC_auroc": [], "HAC_fpr95":[], "HAC_auroc":[]}
metrics = ["fpr95", "auroc"]
for name, group in far_ood_hmdb.groupby(by="method"):
    
    results["method"].append(name)
    for i, dataset in group.iterrows():
        for metric in metrics:
            results[
                f"{dataset['dataset']}_{metric}"
                ].append(dataset[metric])
        

ordre_method = ['msp', 'ebo', 'maxlogit', 'Mahalanobis', 'react', 'ash', 'gen', 'knn', 'vim']
results = pd.DataFrame(results)
results['method'] = pd.Categorical(results['method'], categories=ordre_method, ordered=True)
results = results.sort_values(['method'])
#results.to_csv("tableau7_far_ood_hmdb_++.csv", index=False)
results
# Out:
#         method  UCF_fpr95  UCF_auroc  EPIC_fpr95  EPIC_auroc  HAC_fpr95  \
# 6          msp     40.593     88.000      13.455      96.422     28.620
# 2          ebo     37.058     89.712       7.184      97.598     23.033
# 5     maxlogit     37.058     89.729       7.070      97.726     23.147
# 0  Mahalanobis     27.708     91.211      12.429      96.100      7.754
# 7        react     37.286     89.685       7.184      97.458     20.867
# 1          ash     38.769     89.552       6.956      98.251     23.489
# 3          gen     37.400     91.235       5.131      99.024     24.287
# 4          knn     33.181     91.948       5.587      98.990     13.569
# 8          vim     26.910     92.274       5.587      98.062      6.385
#
#    HAC_auroc
# 6     91.568
# 2     94.447
# 5     94.250
# 0     98.218
# 7     95.056
# 1     94.482
# 3     94.326
# 4     97.248
# 8     98.563
